# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('dirty_healthy_diet_calorie_intake.csv')

# %%
df.head()
# Out:
#   Person_ID   Age  Gender  Height_cm  Weight_kg   BMI     Activity_Level  \
# 0     P0001  50.0    Male      176.4       74.8  24.0        Very Active
# 1     P0002  18.0  Female      167.6       75.5  26.9          Sedentary
# 2     P0003  68.0  Female      161.9       87.2  33.3     Lightly Active
# 3     P0004  22.0  Female      169.3       66.9  23.3  Moderately Active
# 4     P0005  30.0    Male      179.1       75.3  23.5          Sedentary
#
#    Daily_Calorie_Requirement  Daily_Calorie_Consumed  Protein_Intake_g  \
# 0                       2852                  2625.0             183.0
# 1                       1904                  2044.0              90.1
# 2                       2009                  2540.0             222.7
# 3                       2318                  2096.0              69.5
# 4                       2144                  1937.0              32.9
#
#    Carbohydrate_Intake_g  Fat_Intake_g  Water_Intake_Liters     Diet_Type  \
# ...

# %%
df.describe()
# Out:
#                Age    Height_cm    Weight_kg          BMI  \
# count  5703.000000  6000.000000  5761.000000  6000.000000
# mean     48.854638   168.592533    74.097136    26.094300
# std      18.128795     9.160213    12.393398     4.162643
# min      18.000000   145.000000    40.000000    12.900000
# 25%      33.000000   161.700000    65.500000    23.300000
# 50%      48.000000   168.200000    74.200000    26.000000
# 75%      65.000000   175.200000    82.700000    28.900000
# max      80.000000   198.600000   116.600000    44.000000
#
#        Daily_Calorie_Requirement  Daily_Calorie_Consumed  Protein_Intake_g  \
# count                6000.000000             5601.000000       6000.000000
# mean                 2286.223833             2490.622924        123.773150
# std                   469.541134              603.036498         61.999158
# min                  1223.000000             1000.000000         17.400000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Person_ID                  6000 non-null   object
#  1   Age                        5703 non-null   float64
#  2   Gender                     5495 non-null   object
#  3   Height_cm                  6000 non-null   float64
#  4   Weight_kg                  5761 non-null   float64
#  5   BMI                        6000 non-null   float64
#  6   Activity_Level             5692 non-null   object
#  7   Daily_Calorie_Requirement  6000 non-null   int64
#  8   Daily_Calorie_Consumed     5601 non-null   float64
#  9   Protein_Intake_g           6000 non-null   float64
#  10  Carbohydrate_Intake_g      6000 non-null   float64
#  11  Fat_Intake_g               6000 non-null   float64
#  12  Water_Intake_Liters        6000 non-null   float64
# ...

# %%
data1 = df.loc[:,["Person_ID","Health_Status"]]

# %%
data1.isnull().sum()
# Out:
# Person_ID        0
# Health_Status    0
# dtype: int64

# %%
data1.head()
# Out:
#   Person_ID Health_Status
# 0     P0001       Healthy
# 1     P0002    Overweight
# 2     P0003         Obese
# 3     P0004       Healthy
# 4     P0005       Healthy

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(12,6))

sample = data1.head(10)

sns.histplot(data=sample, x='Person_ID')

plt.title('Distribution of First 10 Person IDs')
plt.xlabel('Person ID')
plt.ylabel('Count')

plt.show()
