# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('messy_Student_Social_Media_Mental_Health.csv')

# %%
df.head()
# Out:
#     Age  Gender Country Academic_Level Most_Used_Platform Purpose_Of_Use  \
# 0  21.0    Male   Other  Undergraduate           Facebook     Networking
# 1  23.0  Female   Other       Graduate           LinkedIn      Education
# 2  22.0    Male  Canada  Undergraduate          Instagram  Entertainment
# 3  18.0    Male   Other    High School           Snapchat  Entertainment
# 4  24.0  Female   Other       Graduate           Facebook     Networking
#
#    Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  Physical_Activity_Hours  \
# 0                    4.0          134.0          4.5                      2.2
# 1                    1.6           73.0          7.0                      2.4
# 2                    4.6            NaN          4.0                      1.8
# 3                    7.0          220.0          1.0                      1.7
# 4                    7.5          237.0          1.0                      1.1
#
#    Sleep_Hours_Per_Night Stress_Level  Mental_Health_Score
# 0                    NaN       Medium                  6.8
# 1                    8.6          Low                  7.6
# 2                    6.7       Medium                  7.0
# 3                    5.4    Very High                  5.3
# 4                    5.0    Very High                  4.4

# %%
df.describe()
# Out:
#                Age  Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  \
# count  4750.000000            4750.000000    4750.000000  4750.000000
# mean     20.825474               5.075432     171.572421     3.010884
# std       1.738320               1.660541      42.946790     1.641346
# min      18.000000               1.000000      62.000000     0.300000
# 25%      19.000000               3.800000     140.000000     1.500000
# 50%      21.000000               5.000000     171.000000     2.800000
# 75%      22.000000               6.300000     204.000000     4.200000
# max      24.000000               8.800000     273.000000     8.300000
#
#        Physical_Activity_Hours  Sleep_Hours_Per_Night  Mental_Health_Score
# count              4750.000000            4750.000000          4750.000000
# mean                  1.752105               6.636758             6.232821
# std                   0.666990               1.222270             1.278259
# min                  -0.400000               3.600000             3.600000
# 25%                   1.300000               5.600000             5.100000
# 50%                   1.700000               6.600000             6.100000
# 75%                   2.200000               7.500000             7.100000
# max                   4.100000               9.900000             9.400000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4750 non-null   float64
#  1   Gender                   4750 non-null   object
#  2   Country                  4750 non-null   object
#  3   Academic_Level           4750 non-null   object
#  4   Most_Used_Platform       4750 non-null   object
#  5   Purpose_Of_Use           4750 non-null   object
#  6   Avg_Daily_Usage_Hours    4750 non-null   float64
#  7   Daily_Unlocks            4750 non-null   float64
#  8   Study_Hours              4750 non-null   float64
#  9   Physical_Activity_Hours  4750 non-null   float64
#  10  Sleep_Hours_Per_Night    4750 non-null   float64
#  11  Stress_Level             4750 non-null   object
#  12  Mental_Health_Score      4750 non-null   float64
# dtypes: float64(7), object(6)
# memory usage: 507.9+ KB

# %%
data1 = df.loc[:,["Age"]]

# %%
data1.isnull().sum()
# Out:
# Age    250
# dtype: int64

# %%
data1.head()
# Out:
#     Age
# 0  21.0
# 1  23.0
# 2  22.0
# 3  18.0
# 4  24.0

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(12,6))

sample = data1.head(10)

sns.histplot(data=sample, x='Age')

plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')

plt.show()
